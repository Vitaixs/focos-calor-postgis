# %%
import pandas as pd

df = pd.read_csv("focos_mensal_br_202604.csv")
df.head()
# Out:
#                                      id       lat       lon  \
# 0  4f6a0364-e151-3899-8f9d-cbb3178a89c7 -22.48731 -51.67123
# 1  e1a6ec46-f800-3a93-ba3e-1b1f08710a09 -21.60345 -56.62579
# 2  f66745e6-9f53-3262-8fc7-f313cfb7dd6a -20.03939 -54.50789
# 3  07ee5df2-51cc-3d15-9e16-cb2c5f76a4c8 -20.04072 -54.51852
# 4  f74285dc-5e81-345e-95ec-839d2c090724 -14.44613 -58.43882
#
#          data_hora_gmt   satelite         municipio              estado  \
# 0  2026-04-01 00:37:00  TERRA_M-M  ESTRELA DO NORTE           SÃO PAULO
# 1  2026-04-01 00:37:00  TERRA_M-M        BELA VISTA  MATO GROSSO DO SUL
# 2  2026-04-01 00:37:00  TERRA_M-M         JARAGUARI  MATO GROSSO DO SUL
# 3  2026-04-01 00:37:00  TERRA_M-M         JARAGUARI  MATO GROSSO DO SUL
# 4  2026-04-01 00:39:00  TERRA_M-M  TANGARÁ DA SERRA         MATO GROSSO
#
#      pais  municipio_id  estado_id  pais_id  numero_dias_sem_chuva  \
# 0  Brasil       3515301         35       33                      6
# 1  Brasil       5002100         50       33                      3
# 2  Brasil       5004908         50       33                      0
# 3  Brasil       5004908         50       33                      0
# 4  Brasil       5107958         51       33                      2
#
#    precipitacao  risco_fogo           bioma   frp
# 0          6.24        0.33  Mata Atlântica   7.6
# 1          1.94        0.09         Cerrado  24.5
# 2          0.01        0.17         Cerrado   8.3
# 3          0.00        0.14         Cerrado  16.7
# 4          4.03        0.03         Cerrado  18.1

# %%
df.columns
# Out:
# Index(['id', 'lat', 'lon', 'data_hora_gmt', 'satelite', 'municipio', 'estado',
#        'pais', 'municipio_id', 'estado_id', 'pais_id', 'numero_dias_sem_chuva',
#        'precipitacao', 'risco_fogo', 'bioma', 'frp'],
#       dtype='str')

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:1234@localhost:5432/focosdb")

# %%
import pandas as pd

pd.read_sql("SELECT version();", engine)
# Out:
#                                              version
# 0  PostgreSQL 18.4 on x86_64-windows, compiled by...

# %%
df_reduzido = df[['id', 'lat', 'lon', 'data_hora_gmt', 'municipio', 'estado', 'bioma']]
df_reduzido.head()
# Out:
#                                      id       lat       lon  \
# 0  4f6a0364-e151-3899-8f9d-cbb3178a89c7 -22.48731 -51.67123
# 1  e1a6ec46-f800-3a93-ba3e-1b1f08710a09 -21.60345 -56.62579
# 2  f66745e6-9f53-3262-8fc7-f313cfb7dd6a -20.03939 -54.50789
# 3  07ee5df2-51cc-3d15-9e16-cb2c5f76a4c8 -20.04072 -54.51852
# 4  f74285dc-5e81-345e-95ec-839d2c090724 -14.44613 -58.43882
#
#          data_hora_gmt         municipio              estado           bioma
# 0  2026-04-01 00:37:00  ESTRELA DO NORTE           SÃO PAULO  Mata Atlântica
# 1  2026-04-01 00:37:00        BELA VISTA  MATO GROSSO DO SUL         Cerrado
# 2  2026-04-01 00:37:00         JARAGUARI  MATO GROSSO DO SUL         Cerrado
# 3  2026-04-01 00:37:00         JARAGUARI  MATO GROSSO DO SUL         Cerrado
# 4  2026-04-01 00:39:00  TANGARÁ DA SERRA         MATO GROSSO         Cerrado

# %%
df_reduzido['data_hora_gmt'] = pd.to_datetime(df_reduzido['data_hora_gmt'])

# %%
df_reduzido.to_sql(
    "focos",
    engine,
    if_exists="append",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2127, in Connection._exec_insertmany_context(self, dialect, context)
#    2126     else:
# -> 2127         dialect.do_execute(
#    2128             cursor,
#    2129             sub_stmt,
#    2130             sub_params,
#    2131             context,
#    2132         )
#    2134 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# UniqueViolation: ERRO:  duplicar valor da chave viola a restrição de unicidade "focos_pkey"
# DETAIL:  Chave (id)=(4f6a0364-e151-3899-8f9d-cbb3178a89c7) já existe.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1679, in SQLDatabase.execute(self, sql, params)
#    1678 try:
# -> 1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1421, in Connection.execute(self, statement, parameters, execution_options)
#    1420 else:
# -> 1421     return meth(
#    1422         self,
#    1423         distilled_parameters,
#    1424         execution_options or NO_OPTIONS,
#    1425     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1643, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1635 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1636     dialect=dialect,
#    1637     compiled_cache=compiled_cache,
#    (...)   1641     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1642 )
# -> 1643 ret = self._execute_context(
#    1644     dialect,
#    1645     dialect.execution_ctx_cls._init_compiled,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     execution_options,
#    1649     compiled_sql,
#    1650     distilled_parameters,
#    1651     elem,
#    1652     extracted_params,
#    1653     cache_hit=cache_hit,
#    1654 )
#    1655 if has_events:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1846     return self._exec_insertmany_context(dialect, context)
#    1847 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2135, in Connection._exec_insertmany_context(self, dialect, context)
#    2134 except BaseException as e:
# -> 2135     self._handle_dbapi_exception(
#    2136         e,
#    2137         sql_util._long_statement(sub_stmt),
#    2138         sub_params,
#    2139         cursor,
#    2140         context,
#    2141         is_sub_exec=True,
#    2142     )
#    2144 if engine_events:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2365, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2364     assert sqlalchemy_exception is not None
# -> 2365     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2366 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2127, in Connection._exec_insertmany_context(self, dialect, context)
#    2126     else:
# -> 2127         dialect.do_execute(
#    2128             cursor,
#    2129             sub_stmt,
#    2130             sub_params,
#    2131             context,
#    2132         )
#    2134 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) ERRO:  duplicar valor da chave viola a restrição de unicidade "focos_pkey"
# DETAIL:  Chave (id)=(4f6a0364-e151-3899-8f9d-cbb3178a89c7) já existe.
#
# [SQL: INSERT INTO focos (id, lat, lon, data_hora_gmt, municipio, estado, bioma) VALUES (%(id__0)s, %(lat__0)s, %(lon__0)s, %(data_hora_gmt__0)s, %(municipio__0)s, %(estado__0)s, %(bioma__0)s), (%(id__1)s, %(lat__1)s, %(lon__1)s, %(data_hora_gmt__1)s, %(mun ... 118959 characters truncated ... t__999)s, %(lon__999)s, %(data_hora_gmt__999)s, %(municipio__999)s, %(estado__999)s, %(bioma__999)s)]
# [parameters: {'municipio__0': 'ESTRELA DO NORTE', 'bioma__0': 'Mata Atlântica', 'lat__0': -22.48731, 'estado__0': 'SÃO PAULO', 'lon__0': -51.67123, 'id__0': '4f6a0364-e151-3899-8f9d-cbb3178a89c7', 'data_hora_gmt__0': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__1': 'BELA VISTA', 'bioma__1': 'Cerrado', 'lat__1': -21.60345, 'estado__1': 'MATO GROSSO DO SUL', 'lon__1': -56.62579, 'id__1': 'e1a6ec46-f800-3a93-ba3e-1b1f08710a09', 'data_hora_gmt__1': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__2': 'JARAGUARI', 'bioma__2': 'Cerrado', 'lat__2': -20.03939, 'estado__2': 'MATO GROSSO DO SUL', 'lon__2': -54.50789, 'id__2': 'f66745e6-9f53-3262-8fc7-f313cfb7dd6a', 'data_hora_gmt__2': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__3': 'JARAGUARI', 'bioma__3': 'Cerrado', 'lat__3': -20.04072, 'estado__3': 'MATO GROSSO DO SUL', 'lon__3': -54.51852, 'id__3': '07ee5df2-51cc-3d15-9e16-cb2c5f76a4c8', 'data_hora_gmt__3': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__4': 'TANGARÁ DA SERRA', 'bioma__4': 'Cerrado', 'lat__4': -14.44613, 'estado__4': 'MATO GROSSO', 'lon__4': -58.43882, 'id__4': 'f74285dc-5e81-345e-95ec-839d2c090724', 'data_hora_gmt__4': datetime.datetime(2026, 4, 1, 0, 39), 'municipio__5': 'JUÍNA', 'bioma__5': 'Cerrado', 'lat__5': -11.95691, 'estado__5': 'MATO GROSSO', 'lon__5': -58.75452, 'id__5': '73de662d-0b1f-344a-b6ef-81ad217bdbcc', 'data_hora_gmt__5': datetime.datetime(2026, 4, 1, 0, 39), 'municipio__6': 'RONDONÓPOLIS', 'bioma__6': 'Cerrado', 'lat__6': -16.42804, 'estado__6': 'MATO GROSSO', 'lon__6': -54.91321, 'id__6': 'f02be8bb-920d-3b86-8040-6d7401ed9fce', 'data_hora_gmt__6': datetime.datetime(2026, 4, 1, 0, 39), 'municipio__7': 'TANGARÁ DA SERRA' ... 6900 parameters truncated ... 'data_hora_gmt__992': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__993': 'SÃO LEOPOLDO', 'bioma__993': 'Pampa', 'lat__993': -29.746, 'estado__993': 'RIO GRANDE DO SUL', 'lon__993': -51.1978, 'id__993': 'c396d044-34e5-3ce1-9a31-8e194f514ca2', 'data_hora_gmt__993': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__994': 'SANTO ANTÔNIO DA PATRULHA', 'bioma__994': 'Mata Atlântica', 'lat__994': -29.71863, 'estado__994': 'RIO GRANDE DO SUL', 'lon__994': -50.68082, 'id__994': '5cc94499-ad1d-30be-b4ff-61832d4abe15', 'data_hora_gmt__994': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__995': 'SANTO ANTÔNIO DA PATRULHA', 'bioma__995': 'Mata Atlântica', 'lat__995': -29.71353, 'estado__995': 'RIO GRANDE DO SUL', 'lon__995': -50.68407, 'id__995': 'af5137e5-7cbd-3787-8649-099bf398f1dc', 'data_hora_gmt__995': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__996': 'BELA VISTA', 'bioma__996': 'Cerrado', 'lat__996': -22.18314, 'estado__996': 'MATO GROSSO DO SUL', 'lon__996': -56.96658, 'id__996': '66502cb0-da77-3fba-ab41-450e5c232375', 'data_hora_gmt__996': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__997': 'BELA VISTA', 'bioma__997': 'Cerrado', 'lat__997': -22.18411, 'estado__997': 'MATO GROSSO DO SUL', 'lon__997': -56.97681, 'id__997': 'e49bfc3d-0d6a-3db2-9b7d-9cfdbeee5182', 'data_hora_gmt__997': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__998': 'BELA VISTA', 'bioma__998': 'Cerrado', 'lat__998': -22.18133, 'estado__998': 'MATO GROSSO DO SUL', 'lon__998': -56.97356, 'id__998': '7daf0222-37c8-3980-9378-41edaf45cca1', 'data_hora_gmt__998': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__999': 'BELA VISTA', 'bioma__999': 'Cerrado', 'lat__999': -22.17733, 'estado__999': 'MATO GROSSO DO SUL', 'lon__999': -56.97419, 'id__999': 'c73f86c6-f62f-3e51-bf96-6897f3c25732', 'data_hora_gmt__999': datetime.datetime(2026, 4, 3, 4, 8)}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_reduzido.to_sql(
#       2     "focos",
#       3     engine,
#       4     if_exists="append",
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3048         3
#    3049         """  # noqa: E501
#    3050         from pandas.io import sql
#    3051
# -> 3052         return sql.to_sql(
#    3053             self,
#    3054             name,
#    3055             con,
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
#     840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#     844         if_exists=if_exists,
#     845         index=index,
#     846         index_label=index_label,
#     847         schema=schema,
#     848         chunksize=chunksize,
#     849         dtype=dtype,
#     850         method=method,
#     851         engine=engine,
#     852         **engine_kwargs,
#     853     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2037, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2025 sql_engine = get_engine(engine)
#    2027 table = self.prep_table(
#    2028     frame=frame,
#    2029     name=name,
#    (...)   2034     dtype=dtype,
#    2035 )
# -> 2037 total_inserted = sql_engine.insert_records(
#    2038     table=table,
#    2039     con=self.con,
#    2040     frame=frame,
#    2041     name=name,
#    2042     index=index,
#    2043     schema=schema,
#    2044     chunksize=chunksize,
#    2045     method=method,
#    2046     **engine_kwargs,
#    2047 )
#    2049 self.check_case_sensitive(name=name, schema=schema)
#    2050 return total_inserted
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1571, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1568 from sqlalchemy import exc
#    1570 try:
# -> 1571     return table.insert(chunksize=chunksize, method=method)
#    1572 except exc.StatementError as err:
#    1573     # GH34431
#    1574     # https://stackoverflow.com/a/67358288/6067848
#    1575     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1576     )|inf can not be used with MySQL"""
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1122, in SQLTable.insert(self, chunksize, method)
#    1117     break
#    1119 chunk_iter = zip(
#    1120     *(arr[start_i:end_i] for arr in data_list), strict=True
#    1121 )
# -> 1122 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1123 # GH 46891
#    1124 if num_inserted is not None:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1014, in SQLTable._execute_insert(self, conn, keys, data_iter)
#    1002 """
#    1003 Execute SQL statement inserting data
#    1004
#    (...)   1011    Each item contains a list of values to be inserted
#    1012 """
#    1013 data = [dict(zip(keys, row, strict=True)) for row in data_iter]
# -> 1014 result = self.pd_sql.execute(self.table.insert(), data)
#    1015 return result.rowcount
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1681, in SQLDatabase.execute(self, sql, params)
#    1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
# -> 1681     raise DatabaseError(f"Execution failed on sql '{sql}': {exc}") from exc
#
# DatabaseError: Execution failed on sql 'INSERT INTO focos (id, lat, lon, data_hora_gmt, municipio, estado, bioma) VALUES (:id, :lat, :lon, :data_hora_gmt, :municipio, :estado, :bioma)': (psycopg2.errors.UniqueViolation) ERRO:  duplicar valor da chave viola a restrição de unicidade "focos_pkey"
# DETAIL:  Chave (id)=(4f6a0364-e151-3899-8f9d-cbb3178a89c7) já existe.
#
# [SQL: INSERT INTO focos (id, lat, lon, data_hora_gmt, municipio, estado, bioma) VALUES (%(id__0)s, %(lat__0)s, %(lon__0)s, %(data_hora_gmt__0)s, %(municipio__0)s, %(estado__0)s, %(bioma__0)s), (%(id__1)s, %(lat__1)s, %(lon__1)s, %(data_hora_gmt__1)s, %(mun ... 118959 characters truncated ... t__999)s, %(lon__999)s, %(data_hora_gmt__999)s, %(municipio__999)s, %(estado__999)s, %(bioma__999)s)]
# [parameters: {'municipio__0': 'ESTRELA DO NORTE', 'bioma__0': 'Mata Atlântica', 'lat__0': -22.48731, 'estado__0': 'SÃO PAULO', 'lon__0': -51.67123, 'id__0': '4f6a0364-e151-3899-8f9d-cbb3178a89c7', 'data_hora_gmt__0': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__1': 'BELA VISTA', 'bioma__1': 'Cerrado', 'lat__1': -21.60345, 'estado__1': 'MATO GROSSO DO SUL', 'lon__1': -56.62579, 'id__1': 'e1a6ec46-f800-3a93-ba3e-1b1f08710a09', 'data_hora_gmt__1': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__2': 'JARAGUARI', 'bioma__2': 'Cerrado', 'lat__2': -20.03939, 'estado__2': 'MATO GROSSO DO SUL', 'lon__2': -54.50789, 'id__2': 'f66745e6-9f53-3262-8fc7-f313cfb7dd6a', 'data_hora_gmt__2': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__3': 'JARAGUARI', 'bioma__3': 'Cerrado', 'lat__3': -20.04072, 'estado__3': 'MATO GROSSO DO SUL', 'lon__3': -54.51852, 'id__3': '07ee5df2-51cc-3d15-9e16-cb2c5f76a4c8', 'data_hora_gmt__3': datetime.datetime(2026, 4, 1, 0, 37), 'municipio__4': 'TANGARÁ DA SERRA', 'bioma__4': 'Cerrado', 'lat__4': -14.44613, 'estado__4': 'MATO GROSSO', 'lon__4': -58.43882, 'id__4': 'f74285dc-5e81-345e-95ec-839d2c090724', 'data_hora_gmt__4': datetime.datetime(2026, 4, 1, 0, 39), 'municipio__5': 'JUÍNA', 'bioma__5': 'Cerrado', 'lat__5': -11.95691, 'estado__5': 'MATO GROSSO', 'lon__5': -58.75452, 'id__5': '73de662d-0b1f-344a-b6ef-81ad217bdbcc', 'data_hora_gmt__5': datetime.datetime(2026, 4, 1, 0, 39), 'municipio__6': 'RONDONÓPOLIS', 'bioma__6': 'Cerrado', 'lat__6': -16.42804, 'estado__6': 'MATO GROSSO', 'lon__6': -54.91321, 'id__6': 'f02be8bb-920d-3b86-8040-6d7401ed9fce', 'data_hora_gmt__6': datetime.datetime(2026, 4, 1, 0, 39), 'municipio__7': 'TANGARÁ DA SERRA' ... 6900 parameters truncated ... 'data_hora_gmt__992': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__993': 'SÃO LEOPOLDO', 'bioma__993': 'Pampa', 'lat__993': -29.746, 'estado__993': 'RIO GRANDE DO SUL', 'lon__993': -51.1978, 'id__993': 'c396d044-34e5-3ce1-9a31-8e194f514ca2', 'data_hora_gmt__993': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__994': 'SANTO ANTÔNIO DA PATRULHA', 'bioma__994': 'Mata Atlântica', 'lat__994': -29.71863, 'estado__994': 'RIO GRANDE DO SUL', 'lon__994': -50.68082, 'id__994': '5cc94499-ad1d-30be-b4ff-61832d4abe15', 'data_hora_gmt__994': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__995': 'SANTO ANTÔNIO DA PATRULHA', 'bioma__995': 'Mata Atlântica', 'lat__995': -29.71353, 'estado__995': 'RIO GRANDE DO SUL', 'lon__995': -50.68407, 'id__995': 'af5137e5-7cbd-3787-8649-099bf398f1dc', 'data_hora_gmt__995': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__996': 'BELA VISTA', 'bioma__996': 'Cerrado', 'lat__996': -22.18314, 'estado__996': 'MATO GROSSO DO SUL', 'lon__996': -56.96658, 'id__996': '66502cb0-da77-3fba-ab41-450e5c232375', 'data_hora_gmt__996': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__997': 'BELA VISTA', 'bioma__997': 'Cerrado', 'lat__997': -22.18411, 'estado__997': 'MATO GROSSO DO SUL', 'lon__997': -56.97681, 'id__997': 'e49bfc3d-0d6a-3db2-9b7d-9cfdbeee5182', 'data_hora_gmt__997': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__998': 'BELA VISTA', 'bioma__998': 'Cerrado', 'lat__998': -22.18133, 'estado__998': 'MATO GROSSO DO SUL', 'lon__998': -56.97356, 'id__998': '7daf0222-37c8-3980-9378-41edaf45cca1', 'data_hora_gmt__998': datetime.datetime(2026, 4, 3, 4, 8), 'municipio__999': 'BELA VISTA', 'bioma__999': 'Cerrado', 'lat__999': -22.17733, 'estado__999': 'MATO GROSSO DO SUL', 'lon__999': -56.97419, 'id__999': 'c73f86c6-f62f-3e51-bf96-6897f3c25732', 'data_hora_gmt__999': datetime.datetime(2026, 4, 3, 4, 8)}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
pip install flask

# %%
import os

os.makedirs("templates", exist_ok=True)
os.makedirs("static", exist_ok=True)

# %%
# %%writefile templates/index.html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Mapa de Focos de Calor</title>
#
#     <link rel="stylesheet" href="https://unpkg.com/leaflet/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://unpkg.com/leaflet-draw/dist/leaflet.draw.css"/>
#
#     <style>
#         #map {
#             height: 90vh;
#             width: 100%;
#         }
#     </style>
# </head>
# <body>
#
#     <h2>Mapa de Focos de Calor</h2>
#     <div id="map"></div>
#
#     <script src="https://unpkg.com/leaflet/dist/leaflet.js"></script>
#     <script src="https://unpkg.com/leaflet-draw/dist/leaflet.draw.js"></script>
#
#     <script>
#         var map = L.map('map').setView([-14.235, -51.925], 4);
#
#         L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#             attribution: '© OpenStreetMap'
#         }).addTo(map);
#
#         var drawnItems = new L.FeatureGroup();
#         map.addLayer(drawnItems);
#
#         var drawControl = new L.Control.Draw({
#             draw: {
#                 polygon: true,
#                 rectangle: true,
#                 circle: false,
#                 marker: false,
#                 polyline: false,
#                 circlemarker: false
#             },
#             edit: {
#                 featureGroup: drawnItems
#             }
#         });
#
#         map.addControl(drawControl);
#
#         map.on(L.Draw.Event.CREATED, function (e) {
#             var layer = e.layer;
#             drawnItems.addLayer(layer);
#
#             var latlngs = layer.getLatLngs()[0];
#             var coordinates = latlngs.map(function(point) {
#                 return [point.lng, point.lat];
#             });
#
#             fetch("/contar", {
#                 method: "POST",
#                 headers: {
#                     "Content-Type": "application/json"
#                 },
#                 body: JSON.stringify({
#                     coordinates: coordinates
#                 })
#             })
#             .then(response => response.json())
#             .then(data => {
#                 alert("Número de focos na área: " + data.quantidade);
#             });
#         });
#     </script>
#
# </body>
# </html>
# Out:
# Overwriting templates/index.html

# %%
# %%writefile app.py
from flask import Flask, render_template, request, jsonify
from sqlalchemy import create_engine, text

app = Flask(__name__)

engine = create_engine("postgresql://postgres:1234@localhost:5432/focosdb")

@app.route("/")
def home():
    return render_template("index.html")

@app.route("/contar", methods=["POST"])
def contar():
    dados = request.json
    coordenadas = dados["coordinates"]

    coords_text = ", ".join([f"{lon} {lat}" for lon, lat in coordenadas])
    coords_text += f", {coordenadas[0][0]} {coordenadas[0][1]}"

    wkt = f"POLYGON(({coords_text}))"

    query = text(f"""
        SELECT COUNT(*)
        FROM focos
        WHERE ST_Contains(
            ST_GeomFromText(:wkt, 4326),
            geom
        );
    """)

    with engine.connect() as conn:
        resultado = conn.execute(query, {"wkt": wkt}).scalar()

    return jsonify({"quantidade": resultado})

if __name__ == "__main__":
    app.run(debug=True)
# Out:
# Overwriting app.py

# %%
# !python app.py
